# %%
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ![image.png](attachment:f292401e-847e-47a5-af22-9193b7f2a3e5.png)

# %%
x = torch.rand(2,3)

# %%
x
# Out:
# tensor([[0.7635, 0.1913, 0.8567],
#         [0.3899, 0.2844, 0.0857]])

# %%
sm = F.softmax(x, dim=-1)

# %%
sm
# Out:
# tensor([[0.3757, 0.2120, 0.4124],
#         [0.3791, 0.3412, 0.2797]])

# %%
torch.sum(sm, -1, keepdim=True)
# Out:
# tensor([[1.0000],
#         [1.0000]])

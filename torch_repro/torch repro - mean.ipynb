# %%
import torch
from torch import nn

# %% [markdown]
# ![image.png](attachment:5f90f1e6-1a30-4c2d-9921-4172749fa08d.png)

# %%
x = torch.rand(2,4)

# %%
x
# Out:
# tensor([[0.0189, 0.9750, 0.9384, 0.3573],
#         [0.1096, 0.0327, 0.3600, 0.4740]])

# %%
x.mean()
# Out:
# tensor(0.4083)

# %%
x.mean(0)
# Out:
# tensor([0.0643, 0.5038, 0.6492, 0.4157])

# %%
x.mean(0, True)
# Out:
# tensor([[0.0643, 0.5038, 0.6492, 0.4157]])

# %%
x.mean(1)
# Out:
# tensor([0.5724, 0.2441])

# %%
x.mean(1, True)
# Out:
# tensor([[0.5724],
#         [0.2441]])
